# %% [markdown]
# # Create Tests
#
# The next step for creating a DataCamp project in R is creating a few tests using the [`testthat` package](https://github.com/r-lib/testthat), which is how instructors deliver feedback on the code students write in a project. The [testing chapter](http://r-pkgs.had.co.nz/tests.html) in Hadley Wickham's _R packages_ book gets into the details of testing with `testthat`, along with workflow advice and concrete examples.
#
# After installing the necessary libraries (described below), please create tests for the project tasks below, which were taken from a real live DataCamp project!
#
# When complete, please email the link to your forked repo to projects@datacamp.com with the email subject line _DataCamp project tests_. If you have any questions, please reach out to projects@datacamp.com.

# %%
# To be able to run tests locally in the notebook, install the following:
# install.packages("devtools")
# install.packages("testthat")
# devtools::install_github("datacamp/IRkernel.testthat")

# %% [markdown]
# ## An example of a `testthat` test
#
# Instructions to the student in the project:
#
# - Load the `readr` and `dplyr` packages.
# - Load the dataset, `datasets/by_tag_year.csv`, into a variable named `by_tag_year` using the `read_csv()` function (**not** `read.csv()`).
# - Print `by_tag_year`.
#
# A potential **incorrect** submission is as follows. Please process the cell below. *Note: `by_tag_year.csv` exists in a directory named `datasets` in the same directory as this `create_tests.ipynb` notebook.*

# %%
# Load packages
library(readr)

# Load dataset
by_tag_year <- read.csv("datasets/by_tag_year.csv")

# Inspect the dataset
print(by_tag_year)
# Out:
# Warning message:
# "package 'readr' was built under R version 3.5.2"
#       year                        tag number year_total
# 1     2008                  .htaccess     54      58390
# 2     2008                       .net   5910      58390
# 3     2008                   .net-2.0    289      58390
# 4     2008                   .net-3.5    319      58390
# 5     2008                   .net-4.0      6      58390
# 6     2008              .net-assembly      3      58390
# 7     2008                  .net-core      1      58390
# 8     2008                         2d     42      58390
# 9     2008                     32-bit     19      58390
# 10    2008                32bit-64bit      4      58390
# 11    2008                         3d     73      58390
# 12    2008                      64bit    149      58390
# 13    2008                       abap     10      58390
# 14    2008                   absolute      1      58390
# 15    2008                   abstract      5      58390
# 16    2008             abstract-class     27      58390
# 17    2008       abstract-syntax-tree      6      58390
# 18    2008              accelerometer      3      58390
# 19    2008                     access      1      58390
# 20    2008             access-control     12      58390
# 21    2008              accessibility     26      58390
# 22    2008                 access-vba     50      58390
# 23    2008           access-violation      4      58390
# 24    2008                  accordion      9      58390
# 25    2008                        acl     11      58390
# 26    2008                    acrobat     10      58390
# 27    2008                     action     10      58390
# 28    2008             actionlistener      4      58390
# 29    2008               actionmailer      3      58390
# 30    2008               actionscript    136      58390
# 31    2008             actionscript-2     37      58390
# 32    2008             actionscript-3    308      58390
# 33    2008           active-directory    141      58390
# 34    2008                   activemq     27      58390
# 35    2008               activerecord     84      58390
# 36    2008                    activex     80      58390
# 37    2008                      actor      1      58390
# 38    2008                        ada      8      58390
# 39    2008                    adapter      2      58390
# 40    2008                        add      3      58390
# 41    2008                   addclass      1      58390
# 42    2008           addeventlistener      2      58390
# 43    2008                     add-in     53      58390
# 44    2008                   addition      2      58390
# 45    2008                       adfs      1      58390
# 46    2008                      admin     10      58390
# 47    2008                        ado     37      58390
# 48    2008                    ado.net    165      58390
# 49    2008                      adobe     34      58390
# 50    2008                      adodb      9      58390
# 51    2008                        ads      2      58390
# 52    2008                    adsense      3      58390
# 53    2008                        aes     19      58390
# 54    2008                  aggregate     15      58390
# 55    2008        aggregate-functions      8      58390
# 56    2008                aggregation      3      58390
# 57    2008                      agile    121      58390
# 58    2008                        air     77      58390
# 59    2008                        aix     17      58390
# 60    2008                       ajax    599      58390
# 61    2008         ajaxcontroltoolkit     20      58390
# 62    2008                      alert      3      58390
# 63    2008                   alfresco      5      58390
# 64    2008                  algorithm    643      58390
# 65    2008                      alias     18      58390
# 66    2008                  alignment     22      58390
# 67    2008                 allocation      9      58390
# 68    2008                      alpha      8      58390
# 69    2008                     amazon     11      58390
# 70    2008                 amazon-ec2     24      58390
# 71    2008                  amazon-s3     20      58390
# 72    2008        amazon-web-services     21      58390
# 73    2008                       amqp      3      58390
# 74    2008                   analysis     17      58390
# 75    2008                  analytics     15      58390
# 76    2008                     anchor     14      58390
# 77    2008                    android     38      58390
# 78    2008           android-activity      3      58390
# 79    2008           android-emulator      1      58390
# 80    2008       android-linearlayout      1      58390
# 81    2008           android-listview      1      58390
# 82    2008            android-mapview      2      58390
# 83    2008            android-tabhost      1      58390
# 84    2008                      angle      3      58390
# 85    2008               animated-gif      6      58390
# 86    2008                  animation     61      58390
# 87    2008                annotations     42      58390
# 88    2008         anonymous-function      6      58390
# 89    2008                        ant    113      58390
# 90    2008                      antlr     16      58390
# 91    2008                        aop     36      58390
# 92    2008                     apache    379      58390
# 93    2008                    apache2     31      58390
# 94    2008               apache-camel      5      58390
# 95    2008             apache-commons      3      58390
# 96    2008                 apache-pig      1      58390
# 97    2008                 apache-poi      7      58390
# 98    2008           apache-zookeeper      1      58390
# 99    2008                  apex-code      2      58390
# 100   2008                        api    164      58390
# 101   2008                 api-design      8      58390
# 102   2008                 app-config     30      58390
# 103   2008                  appdomain     26      58390
# 104   2008                     append      5      58390
# 105   2008                applescript     28      58390
# 106   2008                     applet     56      58390
# 107   2008                      apply      1      58390
# 108   2008                  app-store     10      58390
# 109   2008                     aptana     15      58390
# 110   2008                     arabic      4      58390
# 111   2008                     arcgis      5      58390
# 112   2008               architecture    260      58390
# 113   2008                    archive     15      58390
# 114   2008                    arduino      9      58390
# 115   2008                  arguments     24      58390
# 116   2008                        arm     23      58390
# 117   2008                  arraylist     22      58390
# 118   2008                     arrays    371      58390
# 119   2008                artifactory      1      58390
# 120   2008    artificial-intelligence     31      58390
# 121   2008                      ascii     35      58390
# 122   2008                       asmx     31      58390
# 123   2008                    asp.net   3789      58390
# 124   2008                asp.net-3.5     14      58390
# 125   2008               asp.net-ajax    159      58390
# 126   2008         asp.net-membership     34      58390
# 127   2008                asp.net-mvc    939      58390
# 128   2008        asp.net-mvc-routing     18      58390
# 129   2008            asp.net-web-api      2      58390
# 130   2008                asp-classic    212      58390
# 131   2008                    aspectj      4      58390
# 132   2008                 assemblies     99      58390
# 133   2008                   assembly     87      58390
# 134   2008                     assert     21      58390
# 135   2008                     assets      1      58390
# 136   2008               associations     14      58390
# 137   2008          associative-array     14      58390
# 138   2008                   asterisk      6      58390
# 139   2008               asynchronous     71      58390
# 140   2008                 at-command      1      58390
# 141   2008                        atl     17      58390
# 142   2008                     atomic     19      58390
# 143   2008                 attachment     16      58390
# 144   2008                 attributes     72      58390
# 145   2008                      audio    143      58390
# 146   2008            audio-recording      4      58390
# 147   2008            audio-streaming      4      58390
# 148   2008          augmented-reality      1      58390
# 149   2008             authentication    223      58390
# 150   2008              authorization     31      58390
# 151   2008              authorize.net      2      58390
# 152   2008               autocomplete     57      58390
# 153   2008                    autofac      3      58390
# 154   2008                 autohotkey      4      58390
# 155   2008             auto-increment      9      58390
# 156   2008                     autoit      1      58390
# 157   2008                 autolayout      1      58390
# 158   2008                   autoload      2      58390
# 159   2008            automated-tests     72      58390
# 160   2008                 automation    123      58390
# 161   2008                  autotools     12      58390
# 162   2008                auto-update     13      58390
# 163   2008                    average      4      58390
# 164   2008                        avr      4      58390
# 165   2008                        awk     23      58390
# 166   2008                        awt     27      58390
# 167   2008                     axapta     14      58390
# 168   2008                       axis     19      58390
# 169   2008                      axis2     11      58390
# 170   2008                      azure     12      58390
# 171   2008                       back      3      58390
# 172   2008                back-button     12      58390
# 173   2008                    backend      3      58390
# 174   2008                 background     20      58390
# 175   2008           background-color      2      58390
# 176   2008           background-image      5      58390
# 177   2008         background-process      4      58390
# 178   2008           backgroundworker     13      58390
# 179   2008                     backup     91      58390
# 180   2008                  bar-chart      1      58390
# 181   2008                    barcode     13      58390
# 182   2008                     base64     26      58390
# 183   2008                       bash    226      58390
# 184   2008       basic-authentication      4      58390
# 185   2008                 batch-file    166      58390
# 186   2008           batch-processing      4      58390
# 187   2008                   bayesian      3      58390
# 188   2008                     bcrypt      1      58390
# 189   2008                        bdd     13      58390
# 190   2008              beautifulsoup      8      58390
# 191   2008               benchmarking     32      58390
# 192   2008                 bigdecimal      4      58390
# 193   2008                 biginteger     13      58390
# 194   2008                      big-o     23      58390
# 195   2008                     binary     56      58390
# 196   2008                binary-data      7      58390
# 197   2008                binaryfiles     14      58390
# 198   2008              binary-search      6      58390
# 199   2008         binary-search-tree      7      58390
# 200   2008                binary-tree     21      58390
# 201   2008                       bind     10      58390
# 202   2008                    binding     68      58390
# 203   2008                       birt     13      58390
# 204   2008                      bison      5      58390
# 205   2008                        bit      6      58390
# 206   2008                  bitbucket      1      58390
# 207   2008           bit-manipulation     49      58390
# 208   2008                     bitmap     25      58390
# 209   2008                  bit-shift      8      58390
# 210   2008          bitwise-operators      5      58390
# 211   2008                    biztalk     48      58390
# 212   2008                 blackberry     33      58390
# 213   2008                    blender      1      58390
# 214   2008                       blob     24      58390
# 215   2008                   blocking      2      58390
# 216   2008                    blogger      4      58390
# 217   2008                      blogs     32      58390
# 218   2008                  bluetooth     13      58390
# 219   2008                       blur      2      58390
# 220   2008                bookmarklet      9      58390
# 221   2008                    boolean     36      58390
# 222   2008              boolean-logic      4      58390
# 223   2008                      boost     97      58390
# 224   2008                 boost-asio     11      58390
# 225   2008               boost-python      2      58390
# 226   2008               boost-spirit      4      58390
# 227   2008                       boot      4      58390
# 228   2008              bootstrapping      7      58390
# 229   2008                     border      9      58390
# 230   2008                       bots     12      58390
# 231   2008               bouncycastle      2      58390
# 232   2008                     branch     53      58390
# 233   2008      branching-and-merging      3      58390
# 234   2008       breadth-first-search      3      58390
# 235   2008                      break      4      58390
# 236   2008                breakpoints     21      58390
# 237   2008                  broadcast      3      58390
# 238   2008                    browser    247      58390
# 239   2008              browser-cache      2      58390
# 240   2008            browser-history      5      58390
# 241   2008                bubble-sort      1      58390
# 242   2008                     buffer     23      58390
# 243   2008              bufferedimage      2      58390
# 244   2008                      build     82      58390
# 245   2008           build-automation    123      58390
# 246   2008                    builder      5      58390
# 247   2008              build-process    155      58390
# 248   2008                 bulkinsert     10      58390
# 249   2008                     bundle      4      58390
# 250   2008      business-intelligence     17      58390
# 251   2008                     button     43      58390
# 252   2008                       byte     11      58390
# 253   2008                  bytearray     13      58390
# 254   2008                   bytecode     13      58390
# 255   2008                          c   1161      58390
# 256   2008                         c#   7473      58390
# 257   2008                     c#-2.0     43      58390
# 258   2008                     c#-3.0     70      58390
# 259   2008                     c#-4.0     16      58390
# 260   2008                        c++   3111      58390
# 261   2008                      c++11     18      58390
# 262   2008                      c++17      1      58390
# 263   2008                 c++builder     28      58390
# 264   2008                    c++-cli     43      58390
# 265   2008                        c99      3      58390
# 266   2008                      cabal      1      58390
# 267   2008                    caching    262      58390
# 268   2008                    cakephp     47      58390
# 269   2008         calculated-columns      5      58390
# 270   2008                 calculator      5      58390
# 271   2008                   calendar     57      58390
# 272   2008                       call      6      58390
# 273   2008                   callback     38      58390
# 274   2008                     camera     13      58390
# 275   2008                     canvas     25      58390
# 276   2008                 capistrano     23      58390
# 277   2008                    captcha     15      58390
# 278   2008                    capture     11      58390
# 279   2008                       cart      3      58390
# 280   2008                        cas     11      58390
# 281   2008                    cascade     13      58390
# 282   2008                       case      7      58390
# 283   2008                    casting     98      58390
# 284   2008             castle-windsor     57      58390
# 285   2008                   category      1      58390
# 286   2008                        cdn      5      58390
# 287   2008                       cell      2      58390
# 288   2008                     center      9      58390
# 289   2008                  centering      3      58390
# 290   2008                     centos      7      58390
# 291   2008                certificate     51      58390
# 292   2008                        cgi     53      58390
# 293   2008                       char     22      58390
# 294   2008                  character     22      58390
# 295   2008         character-encoding     61      58390
# 296   2008                     charts     60      58390
# 297   2008                       chat      9      58390
# 298   2008                    chatbot      2      58390
# 299   2008                   checkbox     28      58390
# 300   2008                   checkout      1      58390
# 301   2008                   checksum     13      58390
# 302   2008                   cherrypy     17      58390
# 303   2008                   children      5      58390
# 304   2008                      chmod      3      58390
# 305   2008                        cin      4      58390
# 306   2008                      clang      1      58390
# 307   2008                      class    156      58390
# 308   2008         classcastexception      3      58390
# 309   2008             classification      2      58390
# 310   2008                classloader     15      58390
# 311   2008                  classpath     37      58390
# 312   2008                  clearcase     23      58390
# 313   2008                      click     13      58390
# 314   2008                  clickonce     48      58390
# 315   2008                     client     30      58390
# 316   2008              client-server     27      58390
# 317   2008                client-side     16      58390
# 318   2008                  clipboard     30      58390
# 319   2008                      clock      5      58390
# 320   2008                    clojure     24      58390
# 321   2008                      clone     25      58390
# 322   2008                   closures     45      58390
# 323   2008                      cloud     25      58390
# 324   2008                        clr     80      58390
# 325   2008           cluster-analysis      7      58390
# 326   2008          cluster-computing     29      58390
# 327   2008                      cmake      4      58390
# 328   2008                        cmd     60      58390
# 329   2008                      cobol     11      58390
# 330   2008                      cocoa    327      58390
# 331   2008                cocoa-touch    380      58390
# 332   2008             cocos2d-iphone      5      58390
# 333   2008              code-analysis     45      58390
# 334   2008                code-behind     14      58390
# 335   2008                 codeblocks      5      58390
# 336   2008                      codec     12      58390
# 337   2008              code-coverage     52      58390
# 338   2008            code-formatting     21      58390
# 339   2008            code-generation     88      58390
# 340   2008                codeigniter     43      58390
# 341   2008             code-injection     12      58390
# 342   2008                code-review     63      58390
# 343   2008               code-signing     17      58390
# 344   2008              code-snippets     32      58390
# 345   2008               coding-style    259      58390
# 346   2008                 coldfusion     83      58390
# 347   2008                  collation     16      58390
# 348   2008                collections    176      58390
# 349   2008        collision-detection     10      58390
# 350   2008                     colors     91      58390
# 351   2008                        com    226      58390
# 352   2008               combinations      3      58390
# 353   2008              combinatorics      5      58390
# 354   2008                   combobox     59      58390
# 355   2008                      comet     15      58390
# 356   2008                com-interop     30      58390
# 357   2008                    command     31      58390
# 358   2008               command-line    247      58390
# 359   2008     command-line-arguments      7      58390
# 360   2008     command-line-interface     28      58390
# 361   2008             command-prompt      6      58390
# 362   2008                   comments     60      58390
# 363   2008                     commit     14      58390
# 364   2008                common-lisp     42      58390
# 365   2008    common-table-expression      7      58390
# 366   2008              communication     40      58390
# 367   2008          compact-framework    132      58390
# 368   2008                    compare     30      58390
# 369   2008                 comparison     91      58390
# 370   2008              compatibility     36      58390
# 371   2008                compilation     56      58390
# 372   2008      compiler-construction    182      58390
# 373   2008            compiler-errors     15      58390
# 374   2008      compiler-optimization      1      58390
# 375   2008          compiler-warnings      7      58390
# 376   2008          complexity-theory     32      58390
# 377   2008                 components     61      58390
# 378   2008                composition      8      58390
# 379   2008                compression     85      58390
# 380   2008     computational-geometry      5      58390
# 381   2008           computer-science     52      58390
# 382   2008            computer-vision      9      58390
# 383   2008                     concat      3      58390
# 384   2008              concatenation     24      58390
# 385   2008                concurrency    134      58390
# 386   2008                  condition      3      58390
# 387   2008                conditional     22      58390
# 388   2008     conditional-formatting      2      58390
# 389   2008     conditional-statements      1      58390
# 390   2008                     config     13      58390
# 391   2008              configuration    235      58390
# 392   2008        configuration-files     39      58390
# 393   2008                  configure      5      58390
# 394   2008                   conflict     10      58390
# 395   2008                    connect      2      58390
# 396   2008                 connection     43      58390
# 397   2008         connection-pooling     18      58390
# 398   2008          connection-string     34      58390
# 399   2008                    console     95      58390
# 400   2008        console-application     15      58390
# 401   2008                      const     33      58390
# 402   2008                  constants     31      58390
# 403   2008                constraints     40      58390
# 404   2008                constructor     81      58390
# 405   2008             contact-form-7      1      58390
# 406   2008                   contacts      1      58390
# 407   2008                 containers     22      58390
# 408   2008                   contains      3      58390
# 409   2008            contenteditable      2      58390
# 410   2008  content-management-system     58      58390
# 411   2008               content-type     20      58390
# 412   2008                contextmenu     23      58390
# 413   2008     continuous-integration    110      58390
# 414   2008                    contour      2      58390
# 415   2008                 controller     21      58390
# 416   2008                   controls    188      58390
# 417   2008                  converter     18      58390
# 418   2008                convolution      1      58390
# 419   2008                    cookies    111      58390
# 420   2008                coordinates      1      58390
# 421   2008                       copy     42      58390
# 422   2008           copy-constructor      3      58390
# 423   2008                 copy-paste     16      58390
# 424   2008                       core      5      58390
# 425   2008             core-animation     26      58390
# 426   2008                 core-audio     10      58390
# 427   2008                  core-data     12      58390
# 428   2008              core-graphics      6      58390
# 429   2008                    couchdb     15      58390
# 430   2008                      count     18      58390
# 431   2008                    counter      2      58390
# 432   2008                       cout      2      58390
# 433   2008                 covariance     12      58390
# 434   2008                       cpan     22      58390
# 435   2008                     cpanel      2      58390
# 436   2008             c-preprocessor     54      58390
# 437   2008                        cpu     34      58390
# 438   2008           cpu-architecture      6      58390
# 439   2008              cpu-registers      5      58390
# 440   2008                  cpu-usage      7      58390
# 441   2008                        cql      3      58390
# 442   2008                      crash     44      58390
# 443   2008              crash-reports      3      58390
# 444   2008               create-table      1      58390
# 445   2008                credentials     14      58390
# 446   2008                credit-card     11      58390
# 447   2008                   criteria     12      58390
# 448   2008                        crm     10      58390
# 449   2008                       cron     39      58390
# 450   2008                    crontab      5      58390
# 451   2008                       crop      2      58390
# 452   2008              cross-browser     83      58390
# 453   2008            cross-compiling      4      58390
# 454   2008               cross-domain     15      58390
# 455   2008             cross-platform    113      58390
# 456   2008                   crosstab      2      58390
# 457   2008                       crud     20      58390
# 458   2008          cruisecontrol.net     73      58390
# 459   2008               cryptography     65      58390
# 460   2008            crystal-reports    109      58390
# 461   2008                       csrf      8      58390
# 462   2008                        css    933      58390
# 463   2008                       css3      7      58390
# 464   2008                  css-float     18      58390
# 465   2008               css-position      6      58390
# 466   2008              css-selectors     23      58390
# 467   2008                 css-tables     14      58390
# 468   2008                  c-strings      2      58390
# 469   2008                        csv     93      58390
# 470   2008                     ctypes      7      58390
# 471   2008                       cube      3      58390
# 472   2008                   cucumber      2      58390
# 473   2008                       cuda     18      58390
# 474   2008                       curl     43      58390
# 475   2008                   currency     28      58390
# 476   2008                     cursor     14      58390
# 477   2008              curve-fitting      1      58390
# 478   2008          custom-attributes      3      58390
# 479   2008            custom-controls     17      58390
# 480   2008              customization     26      58390
# 481   2008                        cut      2      58390
# 482   2008                        cvs     89      58390
# 483   2008                        cxf      4      58390
# 484   2008                      cycle      4      58390
# 485   2008                     cygwin     61      58390
# 486   2008                     cython      1      58390
# 487   2008                          d     16      58390
# 488   2008                     daemon     17      58390
# 489   2008                        dao      9      58390
# 490   2008                  dashboard      5      58390
# 491   2008          data-access-layer     43      58390
# 492   2008              data-analysis      2      58390
# 493   2008           data-annotations      1      58390
# 494   2008                   database   1275      58390
# 495   2008    database-administration      5      58390
# 496   2008        database-connection     27      58390
# 497   2008            database-design    304      58390
# 498   2008         database-migration      1      58390
# 499   2008       database-performance      2      58390
# 500   2008            database-schema      2      58390
# 501   2008               data-binding    250      58390
# 502   2008                datacontext     10      58390
# 503   2008            data-conversion      4      58390
# 504   2008                   datagrid     61      58390
# 505   2008               datagridview     99      58390
# 506   2008          data-manipulation      2      58390
# 507   2008                 datamapper      8      58390
# 508   2008                data-mining      8      58390
# 509   2008              data-modeling     14      58390
# 510   2008                    dataset     90      58390
# 511   2008                 datasource     13      58390
# 512   2008            data-structures    184      58390
# 513   2008                  datatable     57      58390
# 514   2008               datatemplate     12      58390
# 515   2008         data-visualization      8      58390
# 516   2008             data-warehouse     12      58390
# 517   2008                       date    173      58390
# 518   2008                   datediff     10      58390
# 519   2008                date-format      5      58390
# 520   2008            date-formatting      1      58390
# 521   2008                 datepicker     12      58390
# 522   2008                   datetime    221      58390
# 523   2008            datetime-format      2      58390
# 524   2008             datetimepicker      4      58390
# 525   2008                        db2     53      58390
# 526   2008                        dbi     14      58390
# 527   2008                        ddl     19      58390
# 528   2008                   deadlock     25      58390
# 529   2008                     debian     32      58390
# 530   2008                  debugging    540      58390
# 531   2008                    decimal     28      58390
# 532   2008                declaration     14      58390
# 533   2008                     decode      4      58390
# 534   2008                   decoding      2      58390
# 535   2008                  decorator     18      58390
# 536   2008                    default     14      58390
# 537   2008              default-value      7      58390
# 538   2008                 definition     17      58390
# 539   2008                      delay      2      58390
# 540   2008                  delegates     73      58390
# 541   2008                delete-file      1      58390
# 542   2008                 delete-row      1      58390
# 543   2008                  delimiter      3      58390
# 544   2008                     delphi    512      58390
# 545   2008                   delphi-7     15      58390
# 546   2008               dependencies     81      58390
# 547   2008       dependency-injection     68      58390
# 548   2008      dependency-management      4      58390
# 549   2008      dependency-properties     12      58390
# 550   2008                 deployment    289      58390
# 551   2008                 deprecated     11      58390
# 552   2008         depth-first-search      2      58390
# 553   2008                      derby      7      58390
# 554   2008                     design    482      58390
# 555   2008                   designer     25      58390
# 556   2008            design-patterns    405      58390
# 557   2008                    desktop     52      58390
# 558   2008        desktop-application     31      58390
# 559   2008                 destructor     23      58390
# 560   2008                  detection      3      58390
# 561   2008    development-environment     65      58390
# 562   2008                 devexpress     15      58390
# 563   2008                     device     16      58390
# 564   2008              device-driver      3      58390
# 565   2008                    diagram     37      58390
# 566   2008                     dialog     32      58390
# 567   2008                      dicom      2      58390
# 568   2008                 dictionary     85      58390
# 569   2008                       diff     72      58390
# 570   2008          digital-signature      4      58390
# 571   2008                   dijkstra      2      58390
# 572   2008                   direct3d     34      58390
# 573   2008                  directive      1      58390
# 574   2008                  directory     54      58390
# 575   2008        directory-structure     15      58390
# 576   2008                 directshow     20      58390
# 577   2008                    directx     52      58390
# 578   2008                 directx-11      1      58390
# 579   2008                disassembly      5      58390
# 580   2008                 dispatcher      4      58390
# 581   2008                    dispose     28      58390
# 582   2008                   distance      4      58390
# 583   2008                   distinct     14      58390
# 584   2008                distributed     38      58390
# 585   2008      distributed-computing      4      58390
# 586   2008               distribution     12      58390
# 587   2008                   division      5      58390
# 588   2008                     django    299      58390
# 589   2008               django-admin     10      58390
# 590   2008      django-authentication      3      58390
# 591   2008               django-forms     13      58390
# 592   2008              django-models     37      58390
# 593   2008                 django-orm      1      58390
# 594   2008            django-queryset      1      58390
# 595   2008           django-templates     22      58390
# 596   2008                django-urls      7      58390
# 597   2008               django-views      1      58390
# 598   2008                        dll    195      58390
# 599   2008                  dllimport      6      58390
# 600   2008                        dns    102      58390
# 601   2008                   doctrine      9      58390
# 602   2008                  doctrine2      1      58390
# 603   2008                    doctype      9      58390
# 604   2008                   document     12      58390
# 605   2008              documentation     98      58390
# 606   2008                       docx      9      58390
# 607   2008                       dojo     35      58390
# 608   2008                        dom    179      58390
# 609   2008       domain-driven-design     45      58390
# 610   2008                     dompdf      1      58390
# 611   2008                        dos     29      58390
# 612   2008                 dotnetnuke     28      58390
# 613   2008             dotnetopenauth      6      58390
# 614   2008                     double     23      58390
# 615   2008                   do-while      1      58390
# 616   2008                   download     57      58390
# 617   2008                    doxygen     10      58390
# 618   2008                        dql      1      58390
# 619   2008              drag-and-drop     47      58390
# 620   2008                  draggable      7      58390
# 621   2008                       draw      3      58390
# 622   2008                    drawing     33      58390
# 623   2008                dreamweaver      9      58390
# 624   2008                     driver     10      58390
# 625   2008                     drools      4      58390
# 626   2008                    dropbox      2      58390
# 627   2008             drop-down-menu     69      58390
# 628   2008                     drupal     52      58390
# 629   2008                   drupal-6      6      58390
# 630   2008             drupal-modules      1      58390
# 631   2008               drupal-views      8      58390
# 632   2008                        dry     10      58390
# 633   2008                        dsl     29      58390
# 634   2008                        dtd     21      58390
# 635   2008                        dto      3      58390
# 636   2008                       dump     12      58390
# 637   2008                 duplicates     19      58390
# 638   2008                    dynamic     64      58390
# 639   2008            dynamic-linking     10      58390
# 640   2008        dynamic-programming      3      58390
# 641   2008               dynamics-crm     19      58390
# 642   2008                dynamic-sql      7      58390
# 643   2008                       each      3      58390
# 644   2008                        ear      2      58390
# 645   2008                       ebay      2      58390
# 646   2008                       echo      4      58390
# 647   2008                    eclipse    509      58390
# 648   2008                eclipse-cdt     14      58390
# 649   2008                eclipselink      1      58390
# 650   2008             eclipse-plugin     60      58390
# 651   2008                eclipse-rcp     11      58390
# 652   2008                 e-commerce     18      58390
# 653   2008                       edit      2      58390
# 654   2008                     editor    141      58390
# 655   2008                    ehcache      6      58390
# 656   2008                   ejabberd      1      58390
# 657   2008                        ejb     32      58390
# 658   2008                    ejb-3.0     16      58390
# 659   2008                         el      8      58390
# 660   2008                    element      5      58390
# 661   2008                   elements      3      58390
# 662   2008                elementtree      5      58390
# 663   2008                        elf      8      58390
# 664   2008                      elisp     27      58390
# 665   2008                      emacs    197      58390
# 666   2008                      email    270      58390
# 667   2008                      embed     27      58390
# 668   2008                   embedded    134      58390
# 669   2008          embedded-resource      9      58390
# 670   2008                  emulation     23      58390
# 671   2008              encapsulation     19      58390
# 672   2008                     encode      6      58390
# 673   2008                   encoding    138      58390
# 674   2008                 encryption    174      58390
# 675   2008                 endianness     12      58390
# 676   2008       enterprise-architect      1      58390
# 677   2008         enterprise-library     42      58390
# 678   2008                     entity      8      58390
# 679   2008           entity-framework    150      58390
# 680   2008              entitymanager      1      58390
# 681   2008        entity-relationship     16      58390
# 682   2008                enumeration     29      58390
# 683   2008                      enums    121      58390
# 684   2008                environment     24      58390
# 685   2008      environment-variables     25      58390
# 686   2008                        eof      1      58390
# 687   2008                   equality     12      58390
# 688   2008                     equals     19      58390
# 689   2008                   equation      8      58390
# 690   2008                        erb      7      58390
# 691   2008                     erlang     47      58390
# 692   2008             error-handling    116      58390
# 693   2008                        esb     15      58390
# 694   2008                   escaping     47      58390
# 695   2008                   ethernet      8      58390
# 696   2008                        etl     12      58390
# 697   2008                       eval     14      58390
# 698   2008             event-handling     54      58390
# 699   2008             event-listener      3      58390
# 700   2008                  event-log     16      58390
# 701   2008                     events    276      58390
# 702   2008             exc-bad-access      1      58390
# 703   2008                      excel    399      58390
# 704   2008                 excel-2007     15      58390
# 705   2008              excel-formula      8      58390
# 706   2008                  excel-vba    138      58390
# 707   2008                  exception    378      58390
# 708   2008         exception-handling     92      58390
# 709   2008            exchange-server     57      58390
# 710   2008        exchangewebservices      5      58390
# 711   2008                        exe     12      58390
# 712   2008                       exec     10      58390
# 713   2008                 executable     22      58390
# 714   2008             executable-jar      9      58390
# 715   2008                    execute      1      58390
# 716   2008                  execution      3      58390
# 717   2008            executorservice      4      58390
# 718   2008                       exif      9      58390
# 719   2008                     exists      5      58390
# 720   2008                       exit      7      58390
# 721   2008                     expect      3      58390
# 722   2008                    explode      2      58390
# 723   2008                     export     47      58390
# 724   2008            export-to-excel     11      58390
# 725   2008                 expression     21      58390
# 726   2008           expression-blend     18      58390
# 727   2008           expressionengine      2      58390
# 728   2008           expression-trees     22      58390
# 729   2008                     extend      3      58390
# 730   2008                    extends      3      58390
# 731   2008          extension-methods     59      58390
# 732   2008                     extern      3      58390
# 733   2008                   external     11      58390
# 734   2008                      extjs     27      58390
# 735   2008                    extract     17      58390
# 736   2008                         f#     98      58390
# 737   2008                   facebook     37      58390
# 738   2008                   facelets     10      58390
# 739   2008                    factory     25      58390
# 740   2008            factory-pattern      1      58390
# 741   2008                       fade      5      58390
# 742   2008                    fastcgi     28      58390
# 743   2008                fatal-error      3      58390
# 744   2008                    favicon     13      58390
# 745   2008                     fedora      8      58390
# 746   2008                       feed      8      58390
# 747   2008                      fetch      1      58390
# 748   2008                     ffmpeg     12      58390
# 749   2008                        fft      6      58390
# 750   2008                      fgets      2      58390
# 751   2008                  fibonacci      4      58390
# 752   2008                    fiddler      4      58390
# 753   2008                      field     24      58390
# 754   2008                       file    331      58390
# 755   2008              file-handling      1      58390
# 756   2008                    file-io    154      58390
# 757   2008                  filemaker      2      58390
# 758   2008                  filenames     13      58390
# 759   2008                   filepath      4      58390
# 760   2008           file-permissions     23      58390
# 761   2008                 filereader      2      58390
# 762   2008                   filesize      9      58390
# 763   2008                 filestream      8      58390
# 764   2008                filesystems    134      58390
# 765   2008              file-transfer      6      58390
# 766   2008                file-upload     63      58390
# 767   2008                     filter     25      58390
# 768   2008                  filtering     21      58390
# 769   2008                      final      9      58390
# 770   2008                    finance      9      58390
# 771   2008                       find     16      58390
# 772   2008                   firebird     22      58390
# 773   2008                    firebug     33      58390
# 774   2008                    firefox    267      58390
# 775   2008              firefox-addon     18      58390
# 776   2008                   firewall     17      58390
# 777   2008                      fixed      1      58390
# 778   2008                      flags     10      58390
# 779   2008                      flash    459      58390
# 780   2008                       flex    461      58390
# 781   2008                      flex3     18      58390
# 782   2008                 flex-lexer      5      58390
# 783   2008                     flickr     10      58390
# 784   2008             floating-point     83      58390
# 785   2008                       flot      2      58390
# 786   2008          fluent-nhibernate     21      58390
# 787   2008                      fluid      1      58390
# 788   2008                      focus     35      58390
# 789   2008                     folder      9      58390
# 790   2008                    folders     19      58390
# 791   2008                  font-face      1      58390
# 792   2008                      fonts    104      58390
# 793   2008                  font-size     12      58390
# 794   2008                     footer      6      58390
# 795   2008                      fopen      7      58390
# 796   2008                    foreach     29      58390
# 797   2008   foreign-key-relationship      5      58390
# 798   2008               foreign-keys     38      58390
# 799   2008                       fork     18      58390
# 800   2008                   for-loop     26      58390
# 801   2008                     format     32      58390
# 802   2008                 formatting    112      58390
# 803   2008                      forms    196      58390
# 804   2008       forms-authentication     36      58390
# 805   2008                form-submit      5      58390
# 806   2008                    formula      4      58390
# 807   2008                    fortran     15      58390
# 808   2008                       fpdf      3      58390
# 809   2008                       fpga      5      58390
# 810   2008                      frame      5      58390
# 811   2008                 frame-rate      5      58390
# 812   2008                 frameworks    169      58390
# 813   2008                       free      1      58390
# 814   2008                    freebsd     15      58390
# 815   2008                 freemarker     12      58390
# 816   2008                 freepascal      2      58390
# 817   2008                     freeze      4      58390
# 818   2008                  frequency      5      58390
# 819   2008                     friend     11      58390
# 820   2008                   frontend     10      58390
# 821   2008                    fstream      7      58390
# 822   2008                        ftp     96      58390
# 823   2008                 fullscreen     13      58390
# 824   2008           full-text-search     80      58390
# 825   2008                   function    127      58390
# 826   2008     functional-programming    153      58390
# 827   2008         functional-testing      4      58390
# 828   2008          function-pointers     15      58390
# 829   2008                    functor      5      58390
# 830   2008                     future      2      58390
# 831   2008                     fwrite      2      58390
# 832   2008                        g++     21      58390
# 833   2008                    gallery      2      58390
# 834   2008         garbage-collection     93      58390
# 835   2008                   gaussian      3      58390
# 836   2008                       gawk      5      58390
# 837   2008                        gcc    147      58390
# 838   2008                         gd     19      58390
# 839   2008                       gdal      1      58390
# 840   2008                        gdb     53      58390
# 841   2008                        gdi     30      58390
# 842   2008                       gdi+     48      58390
# 843   2008                        gem     15      58390
# 844   2008                  generator     18      58390
# 845   2008                   generics    345      58390
# 846   2008          genetic-algorithm      7      58390
# 847   2008                  geocoding     16      58390
# 848   2008                geolocation     24      58390
# 849   2008                   geometry     71      58390
# 850   2008                 geospatial      3      58390
# 851   2008                        get     23      58390
# 852   2008             getelementbyid      1      58390
# 853   2008                    getjson      1      58390
# 854   2008                    getline      1      58390
# ...
# 24716 2015                      babel     27    2219527
# 24717 2015                    babeljs    799    2219527
# 24718 2015                       back    157    2219527
# 24719 2015                backbone.js   2400    2219527
# 24720 2015             backbone-views    137    2219527
# 24721 2015                back-button    158    2219527
# 24722 2015                    backend    378    2219527
# 24723 2015                 background   1499    2219527
# 24724 2015           background-color    317    2219527
# 24725 2015           background-image    555    2219527
# 24726 2015         background-process    329    2219527
# 24727 2015           backgroundworker    314    2219527
# 24728 2015                     backup    508    2219527
# 24729 2015                     bamboo    180    2219527
# 24730 2015                  bar-chart    550    2219527
# 24731 2015                    barcode    267    2219527
# 24732 2015            barcode-scanner    211    2219527
# 24733 2015                     base64    996    2219527
# 24734 2015                baseadapter    329    2219527
# 24735 2015                       bash  15450    2219527
# 24736 2015       basic-authentication    318    2219527
# 24737 2015                 batch-file   6738    2219527
# 24738 2015           batch-processing    514    2219527
# 24739 2015                   bayesian    127    2219527
# 24740 2015                     bcrypt    173    2219527
# 24741 2015                        bdd    359    2219527
# 24742 2015            beagleboneblack    246    2219527
# 24743 2015            bean-validation    219    2219527
# 24744 2015              beautifulsoup   1619    2219527
# 24745 2015               benchmarking    275    2219527
# 24746 2015                bigcommerce    212    2219527
# 24747 2015                    bigdata   1089    2219527
# 24748 2015                 bigdecimal    223    2219527
# 24749 2015                 biginteger    238    2219527
# 24750 2015                      big-o    652    2219527
# 24751 2015                     binary   1375    2219527
# 24752 2015                binary-data    116    2219527
# 24753 2015                binaryfiles    261    2219527
# 24754 2015              binary-search    273    2219527
# 24755 2015         binary-search-tree    719    2219527
# 24756 2015                binary-tree    666    2219527
# 24757 2015                       bind    351    2219527
# 24758 2015                    binding   1321    2219527
# 24759 2015                  bing-maps    271    2219527
# 24760 2015             bioinformatics    303    2219527
# 24761 2015                       birt    303    2219527
# 24762 2015                      bison    236    2219527
# 24763 2015                        bit    252    2219527
# 24764 2015                  bitbucket    743    2219527
# 24765 2015                    bitcoin    157    2219527
# 24766 2015           bit-manipulation    678    2219527
# 24767 2015                     bitmap   2022    2219527
# 24768 2015                  bit-shift    195    2219527
# 24769 2015          bitwise-operators    335    2219527
# 24770 2015                    biztalk    308    2219527
# 24771 2015                 blackberry    140    2219527
# 24772 2015              blackberry-10    102    2219527
# 24773 2015                      blade    588    2219527
# 24774 2015                    blender    315    2219527
# 24775 2015                       blob    653    2219527
# 24776 2015                      block    392    2219527
# 24777 2015                 blockchain     40    2219527
# 24778 2015                   blocking    140    2219527
# 24779 2015                    blogger    333    2219527
# 24780 2015                      blogs    219    2219527
# 24781 2015                   bluebird    508    2219527
# 24782 2015                  bluetooth   2058    2219527
# 24783 2015        bluetooth-lowenergy    944    2219527
# 24784 2015                       blur    201    2219527
# 24785 2015                      bokeh    307    2219527
# 24786 2015                bookmarklet     81    2219527
# 24787 2015                    boolean   1142    2219527
# 24788 2015              boolean-logic    159    2219527
# 24789 2015                      boost   2824    2219527
# 24790 2015                 boost-asio    402    2219527
# 24791 2015               boost-python    124    2219527
# 24792 2015               boost-spirit    149    2219527
# 24793 2015                       boot    163    2219527
# 24794 2015                bootstrap-4     38    2219527
# 24795 2015            bootstrap-modal    924    2219527
# 24796 2015              bootstrapping    106    2219527
# 24797 2015                     border    548    2219527
# 24798 2015                       boto    500    2219527
# 24799 2015                      boto3    134    2219527
# 24800 2015                       bots    207    2219527
# 24801 2015                     bottle    198    2219527
# 24802 2015               bouncycastle    287    2219527
# 24803 2015                      bower    950    2219527
# 24804 2015                      box2d    302    2219527
# 24805 2015                    box-api     98    2219527
# 24806 2015                    boxplot    251    2219527
# 24807 2015                  braintree    285    2219527
# 24808 2015                     branch    428    2219527
# 24809 2015      branching-and-merging    126    2219527
# 24810 2015       breadth-first-search    220    2219527
# 24811 2015                      break    256    2219527
# 24812 2015                breakpoints    258    2219527
# 24813 2015                     breeze    361    2219527
# 24814 2015                  broadcast    188    2219527
# 24815 2015          broadcastreceiver   1050    2219527
# 24816 2015                    browser   1960    2219527
# 24817 2015              browser-cache    274    2219527
# 24818 2015            browser-history    127    2219527
# 24819 2015                 browserify    952    2219527
# 24820 2015                bubble-sort    172    2219527
# 24821 2015                     buffer    657    2219527
# 24822 2015              bufferedimage    251    2219527
# 24823 2015             bufferedreader    430    2219527
# 24824 2015                      build   1927    2219527
# 24825 2015               build.gradle    969    2219527
# 24826 2015           build-automation     72    2219527
# 24827 2015                    builder    147    2219527
# 24828 2015              build-process    199    2219527
# 24829 2015                     bukkit    295    2219527
# 24830 2015                 bulkinsert    234    2219527
# 24831 2015                     bundle    514    2219527
# 24832 2015                    bundler    354    2219527
# 24833 2015  bundling-and-minification    165    2219527
# 24834 2015      business-intelligence    215    2219527
# 24835 2015                     button   4011    2219527
# 24836 2015                       byte    717    2219527
# 24837 2015                  bytearray    591    2219527
# 24838 2015                   bytecode    231    2219527
# 24839 2015                          c  40286    2219527
# 24840 2015                         c# 155820    2219527
# 24841 2015                     c#-2.0     53    2219527
# 24842 2015                     c#-3.0    156    2219527
# 24843 2015                     c#-4.0   2062    2219527
# 24844 2015                        c++  80258    2219527
# 24845 2015                      c++11   8047    2219527
# 24846 2015                      c++14   1063    2219527
# 24847 2015                      c++17    103    2219527
# 24848 2015                 c++builder    322    2219527
# 24849 2015                    c++-cli    577    2219527
# 24850 2015                       c3p0    133    2219527
# 24851 2015                        c99    183    2219527
# 24852 2015                      cabal    297    2219527
# 24853 2015                    caching   3947    2219527
# 24854 2015                      caffe    368    2219527
# 24855 2015                    cakephp   3569    2219527
# 24856 2015                cakephp-1.3     59    2219527
# 24857 2015                cakephp-2.0    399    2219527
# 24858 2015                cakephp-2.1     26    2219527
# 24859 2015                cakephp-2.3    146    2219527
# 24860 2015                cakephp-3.0   1367    2219527
# 24861 2015                    calayer    259    2219527
# 24862 2015         calculated-columns    180    2219527
# 24863 2015                 calculator    517    2219527
# 24864 2015                   calendar   1552    2219527
# 24865 2015             caliburn.micro    231    2219527
# 24866 2015                       call    569    2219527
# 24867 2015                   callback   1858    2219527
# 24868 2015                     camera   1736    2219527
# 24869 2015                     cancan    110    2219527
# 24870 2015                     canvas   4386    2219527
# 24871 2015                 capistrano    383    2219527
# 24872 2015                    captcha    277    2219527
# 24873 2015                    capture    124    2219527
# 24874 2015                   capybara    697    2219527
# 24875 2015                   carousel    643    2219527
# 24876 2015                carrierwave    391    2219527
# 24877 2015                       cart    251    2219527
# 24878 2015                        cas    196    2219527
# 24879 2015                    cascade    105    2219527
# 24880 2015                       case    805    2219527
# 24881 2015                   casperjs    624    2219527
# 24882 2015                  cassandra   2505    2219527
# 24883 2015              cassandra-2.0    476    2219527
# 24884 2015                    casting   2002    2219527
# 24885 2015             castle-windsor    208    2219527
# 24886 2015                        cat    172    2219527
# 24887 2015                 categories    211    2219527
# 24888 2015                   category    271    2219527
# 24889 2015                        cdi    532    2219527
# 24890 2015                        cdn    279    2219527
# 24891 2015                     celery    772    2219527
# 24892 2015                       cell    598    2219527
# 24893 2015                     center    389    2219527
# 24894 2015                  centering    224    2219527
# 24895 2015                     centos   1547    2219527
# 24896 2015                    centos6    286    2219527
# 24897 2015                    centos7    386    2219527
# 24898 2015                certificate    797    2219527
# 24899 2015                        cgi    488    2219527
# 24900 2015                       chai    264    2219527
# 24901 2015                    channel    146    2219527
# 24902 2015                       char   1463    2219527
# 24903 2015                  character    764    2219527
# 24904 2015         character-encoding   1406    2219527
# 24905 2015                   chart.js    668    2219527
# 24906 2015                     charts   2808    2219527
# 24907 2015                       chat    666    2219527
# 24908 2015                    chatbot     21    2219527
# 24909 2015                   checkbox   3740    2219527
# 24910 2015                   checkout    179    2219527
# 24911 2015                   checksum    157    2219527
# 24912 2015                       chef   1142    2219527
# 24913 2015                chef-recipe    195    2219527
# 24914 2015                   cherrypy    157    2219527
# 24915 2015              child-process    198    2219527
# 24916 2015                   children    152    2219527
# 24917 2015                      chmod    130    2219527
# 24918 2015                 chromecast    331    2219527
# 24919 2015                   chromium    269    2219527
# 24920 2015                        cin    202    2219527
# 24921 2015                     circle    260    2219527
# 24922 2015                   ckeditor   1232    2219527
# 24923 2015      claims-based-identity    178    2219527
# 24924 2015                      clang    959    2219527
# 24925 2015                    clang++    212    2219527
# 24926 2015                      class   7326    2219527
# 24927 2015         classcastexception    197    2219527
# 24928 2015             classification    663    2219527
# 24929 2015                classloader    403    2219527
# 24930 2015     classnotfoundexception    228    2219527
# 24931 2015                  classpath    474    2219527
# 24932 2015                      clear    143    2219527
# 24933 2015                  clearcase    231    2219527
# 24934 2015                      click    860    2219527
# 24935 2015                  clickonce    251    2219527
# 24936 2015                     client    918    2219527
# 24937 2015              client-server    588    2219527
# 24938 2015                client-side    139    2219527
# 24939 2015                      clion    230    2219527
# 24940 2015                  clipboard    327    2219527
# 24941 2015          cllocationmanager    401    2219527
# 24942 2015                      clock    216    2219527
# 24943 2015                    clojure   2020    2219527
# 24944 2015              clojurescript    317    2219527
# 24945 2015                      clone    403    2219527
# 24946 2015                   closures    962    2219527
# 24947 2015                      cloud    772    2219527
# 24948 2015                 cloud9-ide    393    2219527
# 24949 2015                   cloudant    200    2219527
# 24950 2015                   cloudera    319    2219527
# 24951 2015                 cloudflare    235    2219527
# 24952 2015               cloudfoundry    304    2219527
# 24953 2015                   cloudkit    450    2219527
# 24954 2015                        clr    317    2219527
# 24955 2015           cluster-analysis    505    2219527
# 24956 2015          cluster-computing    553    2219527
# 24957 2015                      cmake   1953    2219527
# 24958 2015                        cmd   2855    2219527
# 24959 2015                      cobol    163    2219527
# 24960 2015                      cocoa   3083    2219527
# 24961 2015                  cocoapods   1369    2219527
# 24962 2015                cocoa-touch   1772    2219527
# 24963 2015             cocos2d-iphone    331    2219527
# 24964 2015                  cocos2d-x    722    2219527
# 24965 2015              code-analysis    151    2219527
# 24966 2015                code-behind    174    2219527
# 24967 2015                 codeblocks    512    2219527
# 24968 2015                      codec    113    2219527
# 24969 2015                codeception    277    2219527
# 24970 2015              code-coverage    435    2219527
# 24971 2015             coded-ui-tests    347    2219527
# 24972 2015                 code-first    243    2219527
# 24973 2015      code-first-migrations    371    2219527
# 24974 2015            code-formatting    126    2219527
# 24975 2015            code-generation    251    2219527
# 24976 2015                codeigniter   8441    2219527
# 24977 2015              codeigniter-2    356    2219527
# 24978 2015              codeigniter-3    282    2219527
# 24979 2015             code-injection    237    2219527
# 24980 2015                codenameone    309    2219527
# 24981 2015                code-review     47    2219527
# 24982 2015               code-signing    226    2219527
# 24983 2015              code-snippets    114    2219527
# 24984 2015               coding-style    600    2219527
# 24985 2015               coffeescript   1380    2219527
# 24986 2015                 coldfusion   1301    2219527
# 24987 2015               coldfusion-9    142    2219527
# 24988 2015                   collapse    192    2219527
# 24989 2015                  collation    149    2219527
# 24990 2015                collections   2201    2219527
# 24991 2015                  collision    345    2219527
# 24992 2015        collision-detection    439    2219527
# 24993 2015                   colorbox    107    2219527
# 24994 2015                     colors   2082    2219527
# 24995 2015                        com    895    2219527
# 24996 2015               combinations    556    2219527
# 24997 2015              combinatorics    208    2219527
# 24998 2015                   combobox   2169    2219527
# 24999 2015                      comet     35    2219527
#  [ reached getOption("max.print") -- omitted 15519 rows ]

# %% [markdown]
# Inspect the `testthat` test below, then run the test locally. (Processing the cell above followed by the cell below will run the test locally.)

# %%
# These packages need to be loaded in the first `@tests` cell. 
library(testthat) 
library(IRkernel.testthat)

# The purpose of tests are to try to catch common errors and to 
# give the student a hint on how to resolve these errors.
# The solution should pass the tests.
run_tests({
    test_that("packages are loaded", {
    expect_true("readr" %in% .packages(), info = "Did you load the readr package?")
    expect_true("dplyr" %in% .packages(), info = "Did you load the dplyr package?")
    })
    
    test_that("by_tag_year is correct", {
    expect_is(by_tag_year, "tbl_df", 
        info = "Did you read in by_tag_year with read_csv (not read.csv)?")
    expect_equal(nrow(by_tag_year), 40518, 
        info = "Did you read in by_tag_year with read_csv?")
    })
})
# Out:
# Warning message:
# "package 'testthat' was built under R version 3.5.2"
# 0/2 tests passed
# > fail :: packages are loaded
# success
# "dplyr" %in% .packages() isn't true.
# Did you load the dplyr package?
#
# ---
# > fail :: by_tag_year is correct
# `by_tag_year` inherits from `data.frame` not `tbl_df`.
# Did you read in by_tag_year with read_csv (not read.csv)?
#
# ---

# %% [markdown]
# A potential **correct** submission is as follows. Please process the cell below to overwrite the previous incorrect solution.

# %%
# Load package
library(readr)
library(dplyr)

# Load dataset
by_tag_year <- read_csv("datasets/by_tag_year.csv")

# Inspect the dataset
print(by_tag_year)
# Out:
# Attaching package: 'dplyr'
#
# The following object is masked from 'package:testthat':
#
#     matches
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Parsed with column specification:
# cols(
#   year = col_double(),
#   tag = col_character(),
#   number = col_double(),
#   year_total = col_double()
# )
# # A tibble: 40,518 x 4
#     year tag           number year_total
#    <dbl> <chr>          <dbl>      <dbl>
#  1  2008 .htaccess         54      58390
#  2  2008 .net            5910      58390
#  3  2008 .net-2.0         289      58390
#  4  2008 .net-3.5         319      58390
#  5  2008 .net-4.0           6      58390
#  6  2008 .net-assembly      3      58390
#  7  2008 .net-core          1      58390
#  8  2008 2d                42      58390
#  9  2008 32-bit            19      58390
# 10  2008 32bit-64bit        4      58390
# # ... with 40,508 more rows

# %%
run_tests({
    test_that("packages are loaded", {
    expect_true("readr" %in% .packages(), info = "Did you load the readr package?")
    expect_true("dplyr" %in% .packages(), info = "Did you load the dplyr package?")
    })
    
    test_that("by_tag_year is correct", {
    expect_is(by_tag_year, "tbl_df", 
        info = "Did you read in by_tag_year with read_csv (not read.csv)?")
    expect_equal(nrow(by_tag_year), 40518, 
        info = "Did you read in by_tag_year with read_csv?")
    })
})
# Out:
# 2/2 tests passed

# %% [markdown]
# ## Create a test
# It's your turn to create a test now!
#
# Instructions to the student in the project:
# * Use `mutate()` to add a column called `fraction` to `by_tag_year`, representing `number` divided by `year_total`. Name the new table `by_tag_year_fraction`.
# * Print `by_tag_year_fraction`.
#
# A potential **incorrect** submission is as follows. Please process the cell below.

# %%
# Add fraction column
by_tag_year_fraction <- by_tag_year %>%
  mutate(fraction = num / year_total)

# Print the new table
print(by_tag_year_fraction)
# Out:
# Error in mutate_impl(.data, dots): Evaluation error: object 'num' not found.
# Traceback:
#
# 1. by_tag_year %>% mutate(fraction = num/year_total)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. mutate(., fraction = num/year_total)
# 10. mutate.tbl_df(., fraction = num/year_total)
# 11. mutate_impl(.data, dots)

# %% [markdown]
# Please fill in the following `testthat` test template to test if:
# - `by_tag_year_fraction` is of class `tbl_df`
# - a new column named "fraction" was created (hint: use `colnames()` with the `%in%` operator)
# - the contents of the "fraction" column are correct
#
# Include a helpful feedback message for failing submissions. The test should fail since the above solution is incorrect.

# %%
run_tests({
    test_that("by_tag_year_fraction is of class tbl_df", {
    expect_is(by_tag_year_fraction, "tbl_df", 
        info = "Did you read in by_tag_year_fraction with read_csv (not read.csv)?")    
    })
    test_that("fraction created", 
             {
     expect_true("fraction" %in% colnames(by_tag_year_fraction), info = "Did you create a new variable called fraction?")            
             })
    test_that("fraction contents are correct", {
        expect_equal(by_tag_year_fraction$fraction, (by_tag_year_fraction$number / by_tag_year_fraction$year_total), info = "The contents of the variable do not seem correct.")
    })
    })
# Out:
# 0/3 tests passed
# > error :: by_tag_year_fraction is of class tbl_df
# object 'by_tag_year_fraction' not found
# ---
# > error :: fraction created
# object 'by_tag_year_fraction' not found
# ---
# > error :: fraction contents are correct
# object 'by_tag_year_fraction' not found
# ---

# %% [markdown]
# A potential **correct** solution is as follows. Please process the cell below.

# %%
# Add fraction column
by_tag_year_fraction <- by_tag_year %>%
  mutate(fraction = number / year_total)

# Print the new table
print(by_tag_year_fraction)
# Out:
# # A tibble: 40,518 x 5
#     year tag           number year_total  fraction
#    <dbl> <chr>          <dbl>      <dbl>     <dbl>
#  1  2008 .htaccess         54      58390 0.000925
#  2  2008 .net            5910      58390 0.101
#  3  2008 .net-2.0         289      58390 0.00495
#  4  2008 .net-3.5         319      58390 0.00546
#  5  2008 .net-4.0           6      58390 0.000103
#  6  2008 .net-assembly      3      58390 0.0000514
#  7  2008 .net-core          1      58390 0.0000171
#  8  2008 2d                42      58390 0.000719
#  9  2008 32-bit            19      58390 0.000325
# 10  2008 32bit-64bit        4      58390 0.0000685
# # ... with 40,508 more rows

# %% [markdown]
# Please copy and paste the test you just wrote into the cell below and process it. The test should pass.

# %%
# copy and paste your test here, then process this cell

run_tests({
    test_that("by_tag_year_fraction is of class tbl_df", {
    expect_is(by_tag_year_fraction, "tbl_df", 
        info = "Did you read in by_tag_year_fraction with read_csv (not read.csv)?")    
    })
    test_that("fraction created", 
             {
     expect_true("fraction" %in% colnames(by_tag_year_fraction), info = "Did you create a new variable called fraction?")            
             })
    test_that("fraction contents are correct", {
        expect_equal(by_tag_year_fraction$fraction, (by_tag_year_fraction$number / by_tag_year_fraction$year_total), info = "The contents of the variable do not seem correct.")
    })
    })
# Out:
# 3/3 tests passed
